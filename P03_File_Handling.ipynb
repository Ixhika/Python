# %%
with open("sample.txt","w") as file:
    file.write("Heelo this is ishika \n")
    file.write("This is text file")

# %% [markdown]
# # Reading from txt file

# %%
# Open a file in read mode ('r') and print its contents
with open("sample.txt", "r") as file:
    content = file.read()
    print("Contents of sample.txt:")
    print(content)
# Out:
# Contents of sample.txt:
# Heelo this is ishika
# This is text file

# %% [markdown]
# # CSV

# %%
import csv

# %%
with open("data.csv","w",newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Name","Age","City"])
    writer.writerow(["Ishika",23,"Kolkata"])
    writer.writerow(["Aryan",23,"UP"])

# %% [markdown]
# # Reading csv

# %%
import csv

# %% [markdown]
# with open("data.csv","r") as csvfile:
#     reader = csv.reader(csvfile)
#     for row in reader:
#         print("Row",row)

# %% [markdown]
# # JSON File
